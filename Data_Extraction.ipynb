# %%
#First, imports
import time 
import requests
import json
import csv
import pprint
import pandas as pd
from config import apikey

# %%
#Start by accessing api
base_url=f"https://api.polygon.io/v2/aggs/ticker/"
#Beer=BUDweiser and coors(TAP), Soda=COKE and PEPsi, Coffee=dutchBROS and StarBUX 
tickers=["BUD","TAP","COKE","PEP","BROS","SBUX"]
data_list=[]

# %%
def iterate_months():
    start_month = 11
    for year in range(2021, 2024):
        for month in range(start_month, 12):
            yield f"{year}-{month:02d}-01"
        start_month = 1

# %%
#Responses in following string
# C- Close price                # O- Open price  
# H- High price                 # T- Unix time
# L- Low price                  # V- Volume
# N- Number of transactions     # VW- Volume weighted

# %%
#Gather data and append to a list
for tick in tickers:
    
    #Makes the print a little prettier
    print("-------------------------")
    print(f"Now Finding: {tick}")
    print("-------------------------")
    
    #Iterate, find and append data
    for month in iterate_months():
        
        #Shows the date time
        print(f"Result Date: {month}")
        print("-------------------------")
        
        full_url=base_url+f"{tick}/range/12/month/{month}/{month}?adjusted=true&sort=asc&limit=120&apiKey={apikey}"
        data = requests.get(full_url)
        data_json = data.json()
        formatted_data = pprint.pformat(data_json)
        print(formatted_data)
        data_list.append(data_json)
        if month == "2023-10-01":
            break
            
        #limited to 5 pulls per miniute, timer allows for the sixth call
        time.sleep(12.2) 
    
#Quality of life to say when its done
print("-------------------------")
print(f"Done!")
print("-------------------------")
# Out:
# -------------------------
# Now Finding: BUD
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'b96c696d317acb309694cea34d666489',
#  'results': [{'c': 59.31,
#               'h': 67.91,
#               'l': 52.65,
#               'n': 1957405,
#               'o': 60.21,
#               't': 1635739200000,
#               'v': 195949135.0,
#               'vw': 59.8907}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '581618a83ff307b6c71b9f350906e2bd',
#  'results': [{'c': 53.94,
#               'h': 67.91,
#               'l': 50.59,
#               'n': 2105726,
#               'o': 62.43,
#               't': 1641013200000,
#               'v': 185073263.0,
#               'vw': 58.7384}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'c48b2115350ee1d65f0953b49d303752',
#  'results': [{'c': 55.02,
#               'h': 66.05,
#               'l': 50.59,
#               'n': 2060645,
#               'o': 64.01,
#               't': 1643691600000,
#               'v': 176759102.0,
#               'vw': 57.2436}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'f26f461791f7d778c1b713612ef96d61',
#  'results': [{'c': 52.51,
#               'h': 63.45,
#               'l': 50.59,
#               'n': 2053783,
#               'o': 59.94,
#               't': 1646110800000,
#               'v': 177299717.0,
#               'vw': 55.898}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'dcb6e307582dda19ec9a766ea3eddf19',
#  'results': [{'c': 48.57,
#               'h': 63.45,
#               'l': 47.23,
#               'n': 1951050,
#               'o': 60.79,
#               't': 1648785600000,
#               'v': 160603099.0,
#               'vw': 54.0878}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '91cd7928b2af86f5de3392220ec3bd5d',
#  'results': [{'c': 45.23,
#               'h': 58.37,
#               'l': 44.51,
#               'n': 2004952,
#               'o': 56.98,
#               't': 1651377600000,
#               'v': 170988591.0,
#               'vw': 51.7573}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '79438a0f5a7ad72cf5a45e36d8362147',
#  'results': [{'c': 55.53,
#               'h': 56.59,
#               'l': 44.51,
#               'n': 2015899,
#               'o': 56.4,
#               't': 1654056000000,
#               'v': 172949903.0,
#               'vw': 50.9943}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '841555b075425d4ba110ae0036fe622e',
#  'results': [{'c': 59.37,
#               'h': 61.63,
#               'l': 44.51,
#               'n': 1912934,
#               'o': 53.92,
#               't': 1656648000000,
#               'v': 165669941.0,
#               'vw': 51.654}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5ebd49af0bcb64393ca4fffb5eceb9f1',
#  'results': [{'c': 59.8,
#               'h': 61.89,
#               'l': 44.51,
#               'n': 1925862,
#               'o': 53,
#               't': 1659326400000,
#               'v': 166972811.0,
#               'vw': 52.6036}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '0742a2ab8468adcfd85313d900d68a83',
#  'results': [{'c': 60.79,
#               'h': 61.89,
#               'l': 44.51,
#               'n': 1955362,
#               'o': 47.47,
#               't': 1662004800000,
#               'v': 165184132.0,
#               'vw': 53.8958}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'df287d41733e47cf9459ed0d5cdd348c',
#  'results': [{'c': 62.18,
#               'h': 62.53,
#               'l': 44.51,
#               'n': 2075917,
#               'o': 44.99,
#               't': 1664596800000,
#               'v': 169385926.0,
#               'vw': 56.4788}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd52c04e7898ae349e39360ade35b81b9',
#  'results': [{'c': 65.65,
#               'h': 67.09,
#               'l': 48.685,
#               'n': 2286932,
#               'o': 51.44,
#               't': 1667275200000,
#               'v': 190980699.0,
#               'vw': 60.6309}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'ae18edc6d6fe80208f891990314ea459',
#  'results': [{'c': 56.36,
#               'h': 67.09,
#               'l': 52.93,
#               'n': 3015781,
#               'o': 60.31,
#               't': 1672549200000,
#               'v': 255697533.0,
#               'vw': 60.4331}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'fc8f8d4edbfc35e96923194b360fcd48',
#  'results': [{'c': 58.56,
#               'h': 67.09,
#               'l': 52.93,
#               'n': 3082445,
#               'o': 60.66,
#               't': 1675227600000,
#               'v': 263647158.0,
#               'vw': 60.0174}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '277b7066ba9e007eddc20423e8226581',
#  'results': [{'c': 56.2,
#               'h': 67.09,
#               'l': 52.93,
#               'n': 3223618,
#               'o': 61.2,
#               't': 1677646800000,
#               'v': 282078590.0,
#               'vw': 59.5769}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5710ba5ed72f74b057402d84c6518674',
#  'results': [{'c': 56.44,
#               'h': 67.01,
#               'l': 52.93,
#               'n': 3239070,
#               'o': 66.52,
#               't': 1680321600000,
#               'v': 282846458.0,
#               'vw': 58.8888}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '0e1f7fda8a2a694d6672674159e8a9fd',
#  'results': [{'c': 53.28,
#               'h': 66.32,
#               'l': 51.66,
#               'n': 3257020,
#               'o': 65.11,
#               't': 1682913600000,
#               'v': 275081831.0,
#               'vw': 56.8354}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': '6da46d47afdf504d5cc97dec94610cc8',
#  'results': [{'c': 54.03,
#               'h': 59.21,
#               'l': 51.66,
#               'n': 2721658,
#               'o': 53.71,
#               't': 1685592000000,
#               'v': 232116316.0,
#               'vw': 55.8317}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': '24b13d2d79807fffbab34964a0acf2ee',
#  'results': [{'c': 54.03,
#               'h': 59.21,
#               'l': 51.66,
#               'n': 2068979,
#               'o': 57,
#               't': 1688184000000,
#               'v': 172993082.0,
#               'vw': 55.804}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': '2bf2d048554e9a4b9aa23964d9122a64',
#  'results': [{'c': 54.03,
#               'h': 58.28,
#               'l': 51.66,
#               'n': 1649215,
#               'o': 57.15,
#               't': 1690862400000,
#               'v': 133254481.0,
#               'vw': 55.2414}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': 'f13988f65c44ccfb40d49511f3568b5f',
#  'results': [{'c': 54.03,
#               'h': 57.79,
#               'l': 51.66,
#               'n': 1102850,
#               'o': 56.91,
#               't': 1693540800000,
#               'v': 86761721.0,
#               'vw': 54.5411}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': '9d57d9574f767fd291d9eb3a208f06d4',
#  'results': [{'c': 54.03,
#               'h': 54.7499,
#               'l': 51.66,
#               'n': 624328,
#               'o': 54.51,
#               't': 1696132800000,
#               'v': 49558091.0,
#               'vw': 53.3602}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BUD'}
# -------------------------
# Now Finding: TAP
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '91e2593c9b998dc34b9f88df44671d27',
#  'results': [{'c': 53.77,
#               'h': 57.45,
#               'l': 42.6,
#               'n': 2230835,
#               'o': 44.11,
#               't': 1635739200000,
#               'v': 193433235.0,
#               'vw': 49.1388}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5d513d97e27920f2a609f69237e37934',
#  'results': [{'c': 55.77,
#               'h': 57.45,
#               'l': 46.47,
#               'n': 2422641,
#               'o': 46.54,
#               't': 1641013200000,
#               'v': 194100944.0,
#               'vw': 51.7757}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'ed0783c61309fd905c9790c29b419148',
#  'results': [{'c': 58.22,
#               'h': 59.38,
#               'l': 47.34,
#               'n': 2409340,
#               'o': 47.58,
#               't': 1643691600000,
#               'v': 189620132.0,
#               'vw': 53.0272}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '02e81c7c3a4cd53892f95b2fcbe44e41',
#  'results': [{'c': 56.09,
#               'h': 60.12,
#               'l': 49.12,
#               'n': 2434905,
#               'o': 51.76,
#               't': 1646110800000,
#               'v': 188182783.0,
#               'vw': 54.1061}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '78d0aa0fbf28702f97b326246ad5b32d',
#  'results': [{'c': 49.15,
#               'h': 60.12,
#               'l': 49.1,
#               'n': 2372252,
#               'o': 53.39,
#               't': 1648785600000,
#               'v': 177858495.0,
#               'vw': 54.2744}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '88524aae202a1dae4ebd7cb923b86f0e',
#  'results': [{'c': 48.24,
#               'h': 60.12,
#               'l': 46.685,
#               'n': 2345719,
#               'o': 54.52,
#               't': 1651377600000,
#               'v': 173785804.0,
#               'vw': 53.5571}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'c2c180ce775c82e93054faef34e43bea',
#  'results': [{'c': 53.5,
#               'h': 60.12,
#               'l': 46.685,
#               'n': 2286420,
#               'o': 55.98,
#               't': 1654056000000,
#               'v': 164117982.0,
#               'vw': 52.9584}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'df8eec4ab12127190b6b21582e47dd5e',
#  'results': [{'c': 50.77,
#               'h': 60.12,
#               'l': 46.685,
#               'n': 2250213,
#               'o': 54.48,
#               't': 1656648000000,
#               'v': 159448782.0,
#               'vw': 53.0197}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '1c65430ab3804285455b11284ce3f3e3',
#  'results': [{'c': 49.98,
#               'h': 60.12,
#               'l': 46.685,
#               'n': 2218999,
#               'o': 59.49,
#               't': 1659326400000,
#               'v': 153933353.0,
#               'vw': 51.7091}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '777327a2346be0bc7b9575831e27e0cb',
#  'results': [{'c': 53.5,
#               'h': 56.28,
#               'l': 46.685,
#               'n': 2293933,
#               'o': 50.96,
#               't': 1662004800000,
#               'v': 158599886.0,
#               'vw': 51.2054}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'b8ea331fb53c4ddec80c094310d7299a',
#  'results': [{'c': 50.7,
#               'h': 56.28,
#               'l': 46.685,
#               'n': 2453742,
#               'o': 48.29,
#               't': 1664596800000,
#               'v': 170836918.0,
#               'vw': 51.626}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5178e122502cbabe475293e2c8dadaec',
#  'results': [{'c': 58.71,
#               'h': 59.26,
#               'l': 46.9,
#               'n': 2632656,
#               'o': 50.35,
#               't': 1667275200000,
#               'v': 185506016.0,
#               'vw': 52.6181}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '16bcc20fa5439ec2cd8a5d63d3ac3c22',
#  'results': [{'c': 65.67,
#               'h': 68.13,
#               'l': 48.485,
#               'n': 3218355,
#               'o': 50.55,
#               't': 1672549200000,
#               'v': 240311486.0,
#               'vw': 57.69}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '6862cc1862b2b48ad021068eeab310d6',
#  'results': [{'c': 70.67,
#               'h': 70.7382,
#               'l': 49.32,
#               'n': 3287014,
#               'o': 52.4,
#               't': 1675227600000,
#               'v': 247607380.0,
#               'vw': 60.0345}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '8f7d914c631f3d36d5559a3b5f25a9a2',
#  'results': [{'c': 62.78,
#               'h': 70.9,
#               'l': 49.32,
#               'n': 3405737,
#               'o': 52.88,
#               't': 1677646800000,
#               'v': 255480911.0,
#               'vw': 61.9304}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd152f5f854d2b57dba62a99daef3587c',
#  'results': [{'c': 63.4,
#               'h': 70.9,
#               'l': 51.45,
#               'n': 3326555,
#               'o': 51.81,
#               't': 1680321600000,
#               'v': 247201745.0,
#               'vw': 63.7097}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'ac84e37b0ae595d79df71c7267b136ba',
#  'results': [{'c': 58.34,
#               'h': 70.9,
#               'l': 57.34,
#               'n': 3296120,
#               'o': 59.47,
#               't': 1682913600000,
#               'v': 242219431.0,
#               'vw': 64.4123}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': '268dd76da6352b4b31085a75ec115e78',
#  'results': [{'c': 57.04,
#               'h': 70.9,
#               'l': 56.5,
#               'n': 2699209,
#               'o': 61.51,
#               't': 1685592000000,
#               'v': 191588839.0,
#               'vw': 64.4616}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': 'a80c7cea56724a8482fd9f620cfe3c59',
#  'results': [{'c': 57.04,
#               'h': 70.9,
#               'l': 56.5,
#               'n': 2086354,
#               'o': 65.64,
#               't': 1688184000000,
#               'v': 143993359.0,
#               'vw': 64.0154}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': '76bb65c28b68dd23536cf5e738b0cb4f',
#  'results': [{'c': 57.04,
#               'h': 68.64,
#               'l': 56.5,
#               'n': 1565315,
#               'o': 65.15,
#               't': 1690862400000,
#               'v': 102142442.0,
#               'vw': 62.4634}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': 'ba2a61f5adbf1c90b06210a176786f24',
#  'results': [{'c': 57.04,
#               'h': 65.31,
#               'l': 56.5,
#               'n': 962681,
#               'o': 63.57,
#               't': 1693540800000,
#               'v': 61797609.0,
#               'vw': 61.1362}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': '220e3501e5b3c2408bd3c7c86bb9ad66',
#  'results': [{'c': 57.04,
#               'h': 63.84,
#               'l': 56.5,
#               'n': 544759,
#               'o': 63.52,
#               't': 1696132800000,
#               'v': 34387495.0,
#               'vw': 59.2862}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'TAP'}
# -------------------------
# Now Finding: COKE
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'c37b983bd7d002363f88c270a465c29e',
#  'results': [{'c': 474.8,
#               'h': 638,
#               'l': 400.5855,
#               'n': 338860,
#               'o': 404.99,
#               't': 1635739200000,
#               'v': 4290350.0,
#               'vw': 528.666}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '752038084ffec6bb6521286e6a3fbbab',
#  'results': [{'c': 551.82,
#               'h': 656.11,
#               'l': 420.34,
#               'n': 422823,
#               'o': 616.35,
#               't': 1641013200000,
#               'v': 4898201.0,
#               'vw': 527.0292}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '8dbd2e6164e69e64f3301b6936b58b3b',
#  'results': [{'c': 494.11,
#               'h': 656.11,
#               'l': 420.34,
#               'n': 460406,
#               'o': 576.65,
#               't': 1643691600000,
#               'v': 6426679.0,
#               'vw': 516.5643}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '6ca2d588281551a79e787fadfe13b1c4',
#  'results': [{'c': 527.18,
#               'h': 656.11,
#               'l': 426.402,
#               'n': 458678,
#               'o': 491.77,
#               't': 1646110800000,
#               'v': 6463730.0,
#               'vw': 514.2551}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '2f8b5c7174cf485dac718be2c001a3e8',
#  'results': [{'c': 421.83,
#               'h': 656.11,
#               'l': 420.2097,
#               'n': 444723,
#               'o': 502,
#               't': 1648785600000,
#               'v': 6345015.0,
#               'vw': 511.8945}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '9468b10e8e470ccba639535d2b5d2b55',
#  'results': [{'c': 430.78,
#               'h': 656.11,
#               'l': 405.03,
#               'n': 444453,
#               'o': 443.77,
#               't': 1651377600000,
#               'v': 6381374.0,
#               'vw': 505.4479}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '6ab18a67d7742324bf5ddc5fc7ce3e91',
#  'results': [{'c': 466.44,
#               'h': 656.11,
#               'l': 405.03,
#               'n': 421827,
#               'o': 562.8,
#               't': 1654056000000,
#               'v': 6499636.0,
#               'vw': 499.1969}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'a06351a296d70a5b1839e156c373af85',
#  'results': [{'c': 511.7,
#               'h': 597.485,
#               'l': 405.03,
#               'n': 380407,
#               'o': 558.24,
#               't': 1656648000000,
#               'v': 6414870.0,
#               'vw': 487.5256}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5aabeba0df0050d3e40eb534acdf2ea1',
#  'results': [{'c': 483.42,
#               'h': 555.8239,
#               'l': 405.03,
#               'n': 337607,
#               'o': 514.12,
#               't': 1659326400000,
#               'v': 4850957.0,
#               'vw': 477.6951}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'a4b4653563be9f7f27985ca207eb6edd',
#  'results': [{'c': 570.9,
#               'h': 576,
#               'l': 405.03,
#               'n': 334324,
#               'o': 476.89,
#               't': 1662004800000,
#               'v': 4872410.0,
#               'vw': 479.3821}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5651dc17869a7d7a95fb0f67d7bc0ff5',
#  'results': [{'c': 525.28,
#               'h': 579.85,
#               'l': 412.71,
#               'n': 342082,
#               'o': 416.1,
#               't': 1664596800000,
#               'v': 4904729.0,
#               'vw': 495.7912}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '53eafa3f5029916008254c1576d23b63',
#  'results': [{'c': 560.45,
#               'h': 579.85,
#               'l': 450.85,
#               'n': 328820,
#               'o': 491.28,
#               't': 1667275200000,
#               'v': 4736854.0,
#               'vw': 508.36}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '1e51cc804aa3e5a8fd04b5846c7198a5',
#  'results': [{'c': 639.57,
#               'h': 694.2,
#               'l': 470,
#               'n': 366467,
#               'o': 515.41,
#               't': 1672549200000,
#               'v': 4611313.0,
#               'vw': 569.5161}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '014f69eeffc9cc2a32416486c76e6011',
#  'results': [{'c': 638.5,
#               'h': 694.2,
#               'l': 492.76,
#               'n': 371198,
#               'o': 507.12,
#               't': 1675227600000,
#               'v': 4601969.0,
#               'vw': 591.9576}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '825105ced5bbde5414e2e45223a35591',
#  'results': [{'c': 689.58,
#               'h': 745.53,
#               'l': 495.11,
#               'n': 379581,
#               'o': 557.36,
#               't': 1677646800000,
#               'v': 4661869.0,
#               'vw': 618.9908}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '404c35720f830d090254c39473d19584',
#  'results': [{'c': 655.26,
#               'h': 745.53,
#               'l': 519.14,
#               'n': 387334,
#               'o': 534.99,
#               't': 1680321600000,
#               'v': 4687709.0,
#               'vw': 647.4158}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '7e85c9e7ffc54c757928154f0d6e5f71',
#  'results': [{'c': 625.67,
#               'h': 745.53,
#               'l': 584.69,
#               'n': 395837,
#               'o': 589.32,
#               't': 1682913600000,
#               'v': 4723555.0,
#               'vw': 658.0016}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': '0e0dba74b4b9bd3cd74cd7b6ce006012',
#  'results': [{'c': 640.89,
#               'h': 745.53,
#               'l': 614.22,
#               'n': 334979,
#               'o': 660.41,
#               't': 1685592000000,
#               'v': 4017085.0,
#               'vw': 660.2054}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': 'adceaf41f5984e1bdefa34b522d70dab',
#  'results': [{'c': 640.89,
#               'h': 745.53,
#               'l': 614.22,
#               'n': 257226,
#               'o': 634.49,
#               't': 1688184000000,
#               'v': 3091737.0,
#               'vw': 660.3046}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': '91d5fcafc70f5fe28abf11a27e2d074b',
#  'results': [{'c': 640.89,
#               'h': 745.53,
#               'l': 614.22,
#               'n': 197496,
#               'o': 634.25,
#               't': 1690862400000,
#               'v': 2321240.0,
#               'vw': 668.3974}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': '9a03323a9e4d896a2afda8f793c79470',
#  'results': [{'c': 640.89,
#               'h': 701,
#               'l': 614.22,
#               'n': 126758,
#               'o': 701,
#               't': 1693540800000,
#               'v': 1336429.0,
#               'vw': 648.6104}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': '3793bece175f203dcc4515db8975fb64',
#  'results': [{'c': 640.89,
#               'h': 670,
#               'l': 614.22,
#               'n': 57876,
#               'o': 637.72,
#               't': 1696132800000,
#               'v': 633603,
#               'vw': 636.7849}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'COKE'}
# -------------------------
# Now Finding: PEP
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '60276f74a39401d0e9771d45282bc93b',
#  'results': [{'c': 172.15,
#               'h': 177.24,
#               'l': 153.37,
#               'n': 7799720,
#               'o': 161.2,
#               't': 1635739200000,
#               'v': 604042310.0,
#               'vw': 167.6689}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5f05920a81eb4d790dc5090223bfcac0',
#  'results': [{'c': 166.13,
#               'h': 177.62,
#               'l': 153.37,
#               'n': 8689823,
#               'o': 172.2,
#               't': 1641013200000,
#               'v': 677766860.0,
#               'vw': 167.9066}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '878f569774ae2bbe0da87e9a56e230cc',
#  'results': [{'c': 169.85,
#               'h': 177.62,
#               'l': 153.37,
#               'n': 8441179,
#               'o': 173.15,
#               't': 1643691600000,
#               'v': 645532362.0,
#               'vw': 167.0945}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '7e1ce02dd10cebcbd0c1e5bb585418ec',
#  'results': [{'c': 180.17,
#               'h': 181.07,
#               'l': 153.37,
#               'n': 7970061,
#               'o': 163.07,
#               't': 1646110800000,
#               'v': 598254882.0,
#               'vw': 167.8107}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '786ca3046dca1fe68cf560c3fed99813',
#  'results': [{'c': 168.6,
#               'h': 181.07,
#               'l': 154.8576,
#               'n': 7781960,
#               'o': 167.89,
#               't': 1648785600000,
#               'v': 584754701.0,
#               'vw': 169.8246}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '419725f01b6b2e5042a62c72c22720d6',
#  'results': [{'c': 171.46,
#               'h': 181.07,
#               'l': 154.8576,
#               'n': 7965519,
#               'o': 172.995,
#               't': 1651377600000,
#               'v': 600179237.0,
#               'vw': 169.0204}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '2ffa5645e982731bd1002459434a9763',
#  'results': [{'c': 181.33,
#               'h': 183.58,
#               'l': 154.8576,
#               'n': 7738471,
#               'o': 168.18,
#               't': 1654056000000,
#               'v': 569558724.0,
#               'vw': 170.8474}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '64bb4171188022812a75f8711c0128a0',
#  'results': [{'c': 181.23,
#               'h': 186.84,
#               'l': 160.98,
#               'n': 7574118,
#               'o': 166.74,
#               't': 1656648000000,
#               'v': 566890459.0,
#               'vw': 174.7018}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd9dec894f08ec043c4f58122afaf93f2',
#  'results': [{'c': 169.88,
#               'h': 186.84,
#               'l': 160.98,
#               'n': 7600312,
#               'o': 174.55,
#               't': 1659326400000,
#               'v': 565165245.0,
#               'vw': 175.7339}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'aebd7ce14c08fdf7fc6c8833b6fa0476',
#  'results': [{'c': 176.31,
#               'h': 186.84,
#               'l': 160.98,
#               'n': 8083268,
#               'o': 170.9201,
#               't': 1662004800000,
#               'v': 601469619.0,
#               'vw': 175.0036}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'fadb35bd67c7b262baf4576099186199',
#  'results': [{'c': 179.09,
#               'h': 186.84,
#               'l': 160.98,
#               'n': 8051825,
#               'o': 163.52,
#               't': 1664596800000,
#               'v': 586966686.0,
#               'vw': 176.1001}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '9bcfe20677ca8305a4988f6b28c96ec9',
#  'results': [{'c': 189.71,
#               'h': 190.18,
#               'l': 167.05,
#               'n': 7671600,
#               'o': 180.94,
#               't': 1667275200000,
#               'v': 546772075.0,
#               'vw': 178.0092}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '289f101ca44fed5092c51d28d18964a2',
#  'results': [{'c': 184.89,
#               'h': 196.88,
#               'l': 167.05,
#               'n': 7724140,
#               'o': 180.59,
#               't': 1672549200000,
#               'v': 544020091.0,
#               'vw': 179.9529}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'aaed883250d256c89de323c0de926494',
#  'results': [{'c': 191.36,
#               'h': 196.88,
#               'l': 167.05,
#               'n': 8037588,
#               'o': 170.88,
#               't': 1675227600000,
#               'v': 567840657.0,
#               'vw': 182.2497}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd74ffd30f144b69ce99567587272d694',
#  'results': [{'c': 177.05,
#               'h': 196.88,
#               'l': 169.12,
#               'n': 7991935,
#               'o': 172.32,
#               't': 1677646800000,
#               'v': 548298615.0,
#               'vw': 184.1244}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '1ddeb2bb1a2648829dc723c2beeb5cd0',
#  'results': [{'c': 175.27,
#               'h': 196.88,
#               'l': 173.48,
#               'n': 8105101,
#               'o': 181.9,
#               't': 1680321600000,
#               'v': 546540307.0,
#               'vw': 184.5972}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '2e9d16c95fe20675a2d311397a08c8c3',
#  'results': [{'c': 160.56,
#               'h': 196.88,
#               'l': 155.83,
#               'n': 8940813,
#               'o': 190.45,
#               't': 1682913600000,
#               'v': 604201203.0,
#               'vw': 180.0693}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': 'b6f176f325e1f590e00eabb46876916f',
#  'results': [{'c': 162.28,
#               'h': 192.38,
#               'l': 155.83,
#               'n': 8271602,
#               'o': 182.42,
#               't': 1685592000000,
#               'v': 538474950.0,
#               'vw': 177.1239}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': '2bb8c01b183d326773ac5dbb0008b639',
#  'results': [{'c': 162.28,
#               'h': 192.38,
#               'l': 155.83,
#               'n': 6871374,
#               'o': 184.3,
#               't': 1688184000000,
#               'v': 437529428.0,
#               'vw': 175.5083}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': '6a968eef5211037a0e2cf64a3fe85427',
#  'results': [{'c': 162.28,
#               'h': 189.97,
#               'l': 155.83,
#               'n': 5226139,
#               'o': 187.49,
#               't': 1690862400000,
#               'v': 327147659.0,
#               'vw': 171.5132}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': 'd946a115468dd98fa36a6fd9fdb8563c',
#  'results': [{'c': 162.28,
#               'h': 181.82,
#               'l': 155.83,
#               'n': 3690545,
#               'o': 178.73,
#               't': 1693540800000,
#               'v': 234765826.0,
#               'vw': 167.5198}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': 'dc5ee383ac35cdeb7bfb511cf83748c2',
#  'results': [{'c': 162.28,
#               'h': 170,
#               'l': 155.83,
#               'n': 2239538,
#               'o': 169.08,
#               't': 1696132800000,
#               'v': 138938772.0,
#               'vw': 161.7629}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'PEP'}
# -------------------------
# Now Finding: BROS
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'cbf086f2561e4e6e143804bced1f730d',
#  'results': [{'c': 51.19,
#               'h': 81.4,
#               'l': 38.11,
#               'n': 2639245,
#               'o': 77.5,
#               't': 1635739200000,
#               'v': 236976558.0,
#               'vw': 53.4792}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '446a7b754c0f9c7d758ecc8df215c5c8',
#  'results': [{'c': 36.87,
#               'h': 66,
#               'l': 20.05,
#               'n': 2699940,
#               'o': 51.47,
#               't': 1641013200000,
#               'v': 256441484.0,
#               'vw': 44.2476}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'db61bc0606745b3725d1c3caba75a636',
#  'results': [{'c': 36.24,
#               'h': 66,
#               'l': 20.05,
#               'n': 2413430,
#               'o': 52.02,
#               't': 1643691600000,
#               'v': 227739644.0,
#               'vw': 43.3747}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'error': "You've exceeded the maximum requests per minute, please wait or "
#           'upgrade your subscription to continue. https://polygon.io/pricing',
#  'request_id': 'fa5ad9a9f22f9e389f69223cefb30209',
#  'status': 'ERROR'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '8bdef896f001ec7cefd10f01186720b3',
#  'results': [{'c': 34.19,
#               'h': 58.6942,
#               'l': 20.05,
#               'n': 2058481,
#               'o': 56.43,
#               't': 1648785600000,
#               'v': 186041506.0,
#               'vw': 37.4877}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '930f571bea7e0db68b424fe1fa4adfa0',
#  'results': [{'c': 34.21,
#               'h': 54.18,
#               'l': 20.05,
#               'n': 2014828,
#               'o': 47.8,
#               't': 1651377600000,
#               'v': 180719365.0,
#               'vw': 34.5737}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'e32366cabc0cf2abc90fb0a36b81b1c9',
#  'results': [{'c': 34.11,
#               'h': 54.18,
#               'l': 27.94,
#               'n': 1726725,
#               'o': 37.47,
#               't': 1654056000000,
#               'v': 139577748.0,
#               'vw': 36.8808}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '3992287d333e5ab36b230559f7f31cfd',
#  'results': [{'c': 30.07,
#               'h': 54.18,
#               'l': 27.94,
#               'n': 1794813,
#               'o': 31.67,
#               't': 1656648000000,
#               'v': 137070749.0,
#               'vw': 36.4363}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'f1a4270123806f37fca82fbec97d9b2a',
#  'results': [{'c': 34,
#               'h': 54.18,
#               'l': 26.93,
#               'n': 1954081,
#               'o': 37.25,
#               't': 1659326400000,
#               'v': 147629695.0,
#               'vw': 35.6386}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'f45b9d7dbe3a1614c4af8509cefff196',
#  'results': [{'c': 34.03,
#               'h': 41.4399,
#               'l': 26.93,
#               'n': 1958424,
#               'o': 35.9,
#               't': 1662004800000,
#               'v': 143300441.0,
#               'vw': 33.961}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd798dbba09c674f4fb0a5c0ce73a5607',
#  'results': [{'c': 28.66,
#               'h': 41.4399,
#               'l': 26.93,
#               'n': 1973148,
#               'o': 31.5,
#               't': 1664596800000,
#               'v': 145046280.0,
#               'vw': 33.5112}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'b985445f8e8863281e12d0d8c66af4fb',
#  'results': [{'c': 30.28,
#               'h': 41.4399,
#               'l': 26.93,
#               'n': 1902779,
#               'o': 37.45,
#               't': 1667275200000,
#               'v': 136357976.0,
#               'vw': 33.3457}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '5fc4fbaf6a1ec14b55f8394749273cf0',
#  'results': [{'c': 27.64,
#               'h': 41.4399,
#               'l': 25.451,
#               'n': 1716758,
#               'o': 28.62,
#               't': 1672549200000,
#               'v': 125211410.0,
#               'vw': 31.9529}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '7cfb91ce5721a9cf9d459ec372d65677',
#  'results': [{'c': 28.93,
#               'h': 41.4399,
#               'l': 25.451,
#               'n': 1538338,
#               'o': 38.09,
#               't': 1675227600000,
#               'v': 111463688.0,
#               'vw': 31.2882}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'ef668168174f4b6c32bd721fadac7002',
#  'results': [{'c': 30.68,
#               'h': 35.18,
#               'l': 25.451,
#               'n': 1556183,
#               'o': 33.3,
#               't': 1677646800000,
#               'v': 111888538.0,
#               'vw': 30.1497}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'e4d0d13415c418776a9364725e3b2534',
#  'results': [{'c': 23.69,
#               'h': 35.09,
#               'l': 23.4,
#               'n': 1662558,
#               'o': 31.64,
#               't': 1680321600000,
#               'v': 122548680.0,
#               'vw': 29.1739}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '7d399349fedfd71a2b15281a07bf2257',
#  'results': [{'c': 25.4,
#               'h': 35.09,
#               'l': 22.665,
#               'n': 1722611,
#               'o': 31.34,
#               't': 1682913600000,
#               'v': 127968105.0,
#               'vw': 28.1714}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': 'e44b944fcac423615e7f2fc6473f5322',
#  'results': [{'c': 24.84,
#               'h': 35.09,
#               'l': 22.665,
#               'n': 1430317,
#               'o': 28.24,
#               't': 1685592000000,
#               'v': 106027747.0,
#               'vw': 27.8207}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': '42030988d2a7b6c16837bf92ad82ed24',
#  'results': [{'c': 24.84,
#               'h': 35.09,
#               'l': 22.665,
#               'n': 1215090,
#               'o': 28.42,
#               't': 1688184000000,
#               'v': 91044505.0,
#               'vw': 27.7242}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': '8cabd6b7609bb1c00cde1067a3406e56',
#  'results': [{'c': 24.84,
#               'h': 35.09,
#               'l': 22.665,
#               'n': 1026777,
#               'o': 30.51,
#               't': 1690862400000,
#               'v': 78017987.0,
#               'vw': 27.4586}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': '75205429924c15e31f36d3df1ae3b3a6',
#  'results': [{'c': 24.84,
#               'h': 29.8299,
#               'l': 22.665,
#               'n': 660410,
#               'o': 29.72,
#               't': 1693540800000,
#               'v': 51025647.0,
#               'vw': 25.4074}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': '909504ffc2242f087d9259a5e97dfac0',
#  'results': [{'c': 24.84,
#               'h': 26.43,
#               'l': 22.85,
#               'n': 275867,
#               'o': 23.14,
#               't': 1696132800000,
#               'v': 19952940.0,
#               'vw': 24.7261}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'BROS'}
# -------------------------
# Now Finding: SBUX
# -------------------------
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'f333bf8b5a0aa6a73744b3a33e65e64e',
#  'results': [{'c': 77.92,
#               'h': 117.8,
#               'l': 77.7808,
#               'n': 13062723,
#               'o': 107.225,
#               't': 1635739200000,
#               'v': 1078291028.0,
#               'vw': 97.565}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '2c8a2b23e78cddf677108fc5895e8fb0',
#  'results': [{'c': 78.11,
#               'h': 117.8,
#               'l': 68.39,
#               'n': 14543812,
#               'o': 116.47,
#               't': 1641013200000,
#               'v': 1268762799.0,
#               'vw': 85.3797}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '56d7ca33afbba05cdf0f1db48209e0a2',
#  'results': [{'c': 81.5,
#               'h': 99.15,
#               'l': 68.39,
#               'n': 13518774,
#               'o': 98.4175,
#               't': 1643691600000,
#               'v': 1173504972.0,
#               'vw': 81.7601}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'afc016915922676968ad4ecc1d522889',
#  'results': [{'c': 86.92,
#               'h': 93.5,
#               'l': 68.39,
#               'n': 12863680,
#               'o': 91.49,
#               't': 1646110800000,
#               'v': 1121522615.0,
#               'vw': 80.3283}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '1842870e0c049089bad73b67705237cd',
#  'results': [{'c': 84.7,
#               'h': 93.48,
#               'l': 68.39,
#               'n': 12344026,
#               'o': 91.5,
#               't': 1648785600000,
#               'v': 1073685684.0,
#               'vw': 80.1503}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '908fc026bad618e87cd55e7b25b32c34',
#  'results': [{'c': 86.79,
#               'h': 93.48,
#               'l': 68.39,
#               'n': 11621839,
#               'o': 75.25,
#               't': 1651377600000,
#               'v': 1011212382.0,
#               'vw': 80.8995}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'ae8f30f7570c32c8921e71252a50b346',
#  'results': [{'c': 97.95,
#               'h': 99.53,
#               'l': 70.35,
#               'n': 10737688,
#               'o': 78.75,
#               't': 1654056000000,
#               'v': 909939770.0,
#               'vw': 84.8653}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'a6511dc1838019b068fe5c32ced7eabf',
#  'results': [{'c': 98,
#               'h': 105.54,
#               'l': 75.73,
#               'n': 10429808,
#               'o': 76.73,
#               't': 1656648000000,
#               'v': 872180575.0,
#               'vw': 89.3456}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '0eba5befd830e655442319534127b319',
#  'results': [{'c': 105.04,
#               'h': 107.595,
#               'l': 81.67,
#               'n': 10561846,
#               'o': 84.19,
#               't': 1659326400000,
#               'v': 869370843.0,
#               'vw': 92.3842}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'e04747f515fb6c861279cf9331da1d2c',
#  'results': [{'c': 103.51,
#               'h': 110.83,
#               'l': 81.67,
#               'n': 10929106,
#               'o': 83.7,
#               't': 1662004800000,
#               'v': 889318807.0,
#               'vw': 95.7439}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'db0a1de64c1909196130264533685115',
#  'results': [{'c': 98.34,
#               'h': 110.83,
#               'l': 82.43,
#               'n': 10368190,
#               'o': 84.75,
#               't': 1664596800000,
#               'v': 807709929.0,
#               'vw': 98.4406}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'e2d3165d8a092d6c0f53c7f472c9b6eb',
#  'results': [{'c': 109.34,
#               'h': 111.11,
#               'l': 82.97,
#               'n': 10264416,
#               'o': 88.06,
#               't': 1667275200000,
#               'v': 751122676.0,
#               'vw': 101.7863}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '3ab601f5273d7655d45c1373aa78ed35',
#  'results': [{'c': 98.23,
#               'h': 115.48,
#               'l': 96.52,
#               'n': 11557334,
#               'o': 100.56,
#               't': 1672549200000,
#               'v': 765299042.0,
#               'vw': 103.9128}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '866aa8c30a0887badb15d890664c0e23',
#  'results': [{'c': 102.92,
#               'h': 115.48,
#               'l': 95.55,
#               'n': 11956655,
#               'o': 108.97,
#               't': 1675227600000,
#               'v': 767616004.0,
#               'vw': 102.9306}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '55576300a5f5c97c4a988f829b42ad02',
#  'results': [{'c': 96.46,
#               'h': 115.48,
#               'l': 95.55,
#               'n': 12161541,
#               'o': 102.19,
#               't': 1677646800000,
#               'v': 748323896.0,
#               'vw': 102.1521}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': 'd43caa56d3e81fd18ce1a76e527776dd',
#  'results': [{'c': 93.68,
#               'h': 115.48,
#               'l': 93.03,
#               'n': 12293019,
#               'o': 104.06,
#               't': 1680321600000,
#               'v': 748114848.0,
#               'vw': 101.3726}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 120,
#  'request_id': '6827df0271703a5d8e0f9a712b73c3fd',
#  'results': [{'c': 94.42,
#               'h': 115.48,
#               'l': 89.21,
#               'n': 12317927,
#               'o': 114.252,
#               't': 1682913600000,
#               'v': 757633509.0,
#               'vw': 99.2158}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 105,
#  'request_id': 'c9dce4f873fd0900f3c911c9e9ae3d73',
#  'results': [{'c': 93.15,
#               'h': 104.46,
#               'l': 89.21,
#               'n': 10436555,
#               'o': 97.59,
#               't': 1685592000000,
#               'v': 641122903.0,
#               'vw': 97.5593}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 84,
#  'request_id': 'b121c697c81898962c4590efbf2966e1',
#  'results': [{'c': 93.15,
#               'h': 104.46,
#               'l': 89.21,
#               'n': 8153700,
#               'o': 98.73,
#               't': 1688184000000,
#               'v': 490196641.0,
#               'vw': 97.022}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 64,
#  'request_id': 'a3a445f80150571d025cdc1523808f30',
#  'results': [{'c': 93.15,
#               'h': 104.46,
#               'l': 89.21,
#               'n': 6076093,
#               'o': 101.47,
#               't': 1690862400000,
#               'v': 358852308.0,
#               'vw': 95.675}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 41,
#  'request_id': 'c0e7045853cd3e5b5b08deb4641295f1',
#  'results': [{'c': 93.15,
#               'h': 98.75,
#               'l': 89.21,
#               'n': 3843077,
#               'o': 98.4,
#               't': 1693540800000,
#               'v': 231812477.0,
#               'vw': 93.7673}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# {'adjusted': True,
#  'count': 1,
#  'queryCount': 21,
#  'request_id': 'c923b9384ab83383159dc341fa233fa0',
#  'results': [{'c': 93.15,
#               'h': 95.66,
#               'l': 89.21,
#               'n': 2006197,
#               'o': 91.05,
#               't': 1696132800000,
#               'v': 118681788.0,
#               'vw': 92.7546}],
#  'resultsCount': 1,
#  'status': 'OK',
#  'ticker': 'SBUX'}
# -------------------------
# Done!
# -------------------------

# %%
#Create dataframe
df = pd.DataFrame(data_list)
df.head()
#Visualization for later
#plt.plot(df[""][""])
#plt.title("<TICK> Stock Price")
#plt.show()
# Out:
#   ticker  queryCount  resultsCount adjusted  \
# 0    BUD       120.0           1.0     True
# 1    BUD       120.0           1.0     True
# 2    BUD       120.0           1.0     True
# 3    BUD       120.0           1.0     True
# 4    BUD       120.0           1.0     True
#
#                                              results status  \
# 0  [{'v': 195949135.0, 'vw': 59.8907, 'o': 60.21,...     OK
# 1  [{'v': 185073263.0, 'vw': 58.7384, 'o': 62.43,...     OK
# 2  [{'v': 176759102.0, 'vw': 57.2436, 'o': 64.01,...     OK
# 3  [{'v': 177299717.0, 'vw': 55.898, 'o': 59.94, ...     OK
# 4  [{'v': 160603099.0, 'vw': 54.0878, 'o': 60.79,...     OK
#
#                          request_id  count error
# 0  b96c696d317acb309694cea34d666489    1.0   NaN
# 1  581618a83ff307b6c71b9f350906e2bd    1.0   NaN
# 2  c48b2115350ee1d65f0953b49d303752    1.0   NaN
# 3  f26f461791f7d778c1b713612ef96d61    1.0   NaN
# 4  dcb6e307582dda19ec9a766ea3eddf19    1.0   NaN

# %%
#Clean the dataframe

# %%
#Save data to csv
df.to_csv('data.csv', index=True)
