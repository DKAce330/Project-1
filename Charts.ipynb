# %%
import csv
import pprint
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
from Config import apikey
import seaborn as sns
#Import df from csv
path=("data.csv")
df=pd.read_csv(path)
def fix_unix_time(unix_time_values):
    scaled_time_values = (unix_time_values - min(unix_time_values)) / (max(unix_time_values) - min(unix_time_values))
    return scaled_time_values

# Create a list of Unix time values
t = df['t']

# Convert and scale the Unix time values
st = fix_unix_time(t)

# Add the scaled time values to the DataFrame
df['st'] = st

# Print the DataFrame
df

df
# Out:
#      Unnamed: 0 ticker            v       vw       o       c       h      l  \
# 0             2    BUD  185073263.0  58.7384   62.43   53.94   67.91  50.59
# 1             3    BUD  176759102.0  57.2436   64.01   55.02   66.05  50.59
# 2             4    BUD  177299717.0  55.8980   59.94   52.51   63.45  50.59
# 3             5    BUD  160603099.0  54.0878   60.79   48.57   63.45  47.23
# 4             6    BUD  170988591.0  51.7573   56.98   45.23   58.37  44.51
# ..          ...    ...          ...      ...     ...     ...     ...    ...
# 127         134   SBUX  537193724.0  96.9278   98.73  100.01  104.46  89.21
# 128         135   SBUX  405849391.0  95.7062  101.47  100.01  104.46  89.21
# 129         136   SBUX  278809560.0  94.1343   98.40  100.01  101.92  89.21
# 130         137   SBUX  165678871.0  93.6594   91.05  100.01  101.92  89.21
# 131         138   SBUX   37688828.0  96.7790   91.83  100.01  101.92  90.55
#
#                  t        n        st
# ...

# %%
# Filter the DataFrame by ticker
bud_df = df[df['ticker'] == 'BUD']
coors_df= df[df['ticker'] == 'TAP']
coke_df= df[df['ticker'] == 'KO']
pepsi_df= df[df['ticker'] == 'PEP']
star_df= df[df['ticker'] == 'SBUX']
dutch_df= df[df['ticker'] == 'BROS']

# %%
#Line graphs

x_values = bud_df['st']
y1_values = bud_df['c']
y2_values = coors_df['c']
y3_values = coke_df['c']
y4_values = pepsi_df['c']
y5_values = star_df['c']
y6_values = dutch_df['c']

plt.plot(x_values, y1_values, label='Budweiser')
plt.plot(x_values, y2_values, label='Coors')
plt.plot(x_values, y3_values, label='Coke')
plt.plot(x_values, y4_values, label='Pepsi')
plt.plot(x_values, y5_values, label='Starbucks')
plt.plot(x_values, y6_values, label='Dutch')

plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Beverage Stocks')
plt.legend()
plt.plot
plt.savefig('Graphs/Complete.png')

# %%
#Beer

x_values = bud_df['st']
y1_values = bud_df['c']
y2_values = coors_df['c']

plt.plot(x_values, y1_values, label='Budweiser')
plt.plot(x_values, y2_values, label='Coors')

plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Beer Stocks')
plt.legend()
plt.plot
plt.savefig('Graphs/Beer.png')

# %%
#Soda

x_values = bud_df['st']
y3_values = coke_df['c']
y4_values = pepsi_df['c']
y5_values = star_df['c']
y6_values = dutch_df['c']

plt.plot(x_values, y3_values, label='Coke')
plt.plot(x_values, y4_values, label='Pepsi')

plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Soda Stocks')
plt.legend()
plt.plot
plt.savefig('Graphs/Soda.png')

# %%
#Coffee

y5_values = star_df['c']
y6_values = dutch_df['c']

plt.plot(x_values, y5_values, label='Starbucks')
plt.plot(x_values, y6_values, label='Dutch')

plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Coffee Stocks')
plt.legend()
plt.plot
plt.savefig('Graphs/Coffee Stocks.png')
